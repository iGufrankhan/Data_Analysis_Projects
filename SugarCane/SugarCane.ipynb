# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_1=pd.read_csv('List of Countries by Sugarcane Production.csv')

# %%
data_1.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
data_1.isnull()
# Out:
#      Unnamed: 0  Country  Continent  Production (Tons)  \
# 0         False    False      False              False
# 1         False    False      False              False
# 2         False    False      False              False
# 3         False    False      False              False
# 4         False    False      False              False
# ..          ...      ...        ...                ...
# 98        False    False      False              False
# 99        False    False      False              False
# 100       False    False      False              False
# 101       False    False      False              False
# 102       False    False      False              False
#
#      Production per Person (Kg)  Acreage (Hectare)  Yield (Kg / Hectare)
# 0                         False              False                 False
# 1                         False              False                 False
# 2                         False              False                 False
# ...

# %%
data_1.isnull().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  103 non-null    int64
#  1   Country                     103 non-null    object
#  2   Continent                   103 non-null    object
#  3   Production (Tons)           103 non-null    object
#  4   Production per Person (Kg)  103 non-null    object
#  5   Acreage (Hectare)           102 non-null    object
#  6   Yield (Kg / Hectare)        102 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 5.8+ KB

# %%
data_1['Production (Tons)']=data_1['Production (Tons)'].str.replace(".","")
data_1['Production per Person (Kg)']=data_1['Production per Person (Kg)'].str.replace(".","").str.replace(",",".")
data_1['Acreage (Hectare)']=data_1['Acreage (Hectare)'].str.replace(".","")
data_1['Yield (Kg / Hectare)']=data_1['Yield (Kg / Hectare)'].str.replace(".","").str.replace(",",".")
data_1.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
data_1.isnull().sum()
# Out:
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             1
# Yield (Kg / Hectare)          1
# dtype: int64

# %%
data_1=data_1.dropna().reset_index()

data_1.head()
# Out:
#    index  Unnamed: 0   Country      Continent Production (Tons)  \
# 0      0           0    Brazil  South America         768678382
# 1      1           1     India           Asia         348448000
# 2      2           2     China           Asia         123059739
# 3      3           3  Thailand           Asia          87468496
# 4      4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                   3668.531          10226205              75167.5
# 1                     260721           4950000              70393.5
# 2                      88287           1675215              73459.1
# 3                   1264.303           1336575              65442.2
# 4                     324219           1130820                57879

# %%
data_1.isnull().sum()
# Out:
# index                         0
# Unnamed: 0                    0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             0
# Yield (Kg / Hectare)          0
# dtype: int64

# %%
data_1 = data_1.drop( "Unnamed: 0", axis = 1)

# %%
data_1.isnull().sum()
# Out:
# index                         0
# Country                       0
# Continent                     0
# Production (Tons)             0
# Production per Person (Kg)    0
# Acreage (Hectare)             0
# Yield (Kg / Hectare)          0
# dtype: int64

# %%
data_1 = data_1.drop( "index", axis = 1)

# %%
data_1.head()
# Out:
#     Country      Continent Production (Tons) Production per Person (Kg)  \
# 0    Brazil  South America         768678382                   3668.531
# 1     India           Asia         348448000                     260721
# 2     China           Asia         123059739                      88287
# 3  Thailand           Asia          87468496                   1264.303
# 4  Pakistan           Asia          65450704                     324219
#
#   Acreage (Hectare) Yield (Kg / Hectare)
# 0          10226205              75167.5
# 1           4950000              70393.5
# 2           1675215              73459.1
# 3           1336575              65442.2
# 4           1130820                57879

# %%
data_1.rename(columns= {"Production (Tons)": "Production(Tons)"}, inplace = True)
data_1.rename(columns= {"Production per Person (Kg)": "Production_per_person(Kg)"}, inplace = True)
data_1.rename(columns= {"Acreage (Hectare)": "Acreage(Hectare)"}, inplace = True)
data_1.rename(columns= {"Yield (Kg / Hectare)": "Yield(Kg/Hectare)"}, inplace = True)

# %%
data_1.head()
# Out:
#     Country      Continent Production(Tons) Production_per_person(Kg)  \
# 0    Brazil  South America        768678382                  3668.531
# 1     India           Asia        348448000                    260721
# 2     China           Asia        123059739                     88287
# 3  Thailand           Asia         87468496                  1264.303
# 4  Pakistan           Asia         65450704                    324219
#
#   Acreage(Hectare) Yield(Kg/Hectare)
# 0         10226205           75167.5
# 1          4950000           70393.5
# 2          1675215           73459.1
# 3          1336575           65442.2
# 4          1130820             57879

# %%
data_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Country                    102 non-null    object
#  1   Continent                  102 non-null    object
#  2   Production(Tons)           102 non-null    object
#  3   Production_per_person(Kg)  102 non-null    object
#  4   Acreage(Hectare)           102 non-null    object
#  5   Yield(Kg/Hectare)          102 non-null    object
# dtypes: object(6)
# memory usage: 4.9+ KB

# %%
data_1['Production(Tons)']=data_1['Production(Tons)'].astype(float)
data_1["Production_per_person(Kg)"] = data_1["Production_per_person(Kg)"].astype(float)
data_1["Acreage(Hectare)"] = data_1["Acreage(Hectare)"].astype(float)
data_1["Yield(Kg/Hectare)"] = data_1["Yield(Kg/Hectare)"].astype(float)
data_1.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %%
data_1.dtypes
# Out:
# Country                       object
# Continent                     object
# Production(Tons)             float64
# Production_per_person(Kg)    float64
# Acreage(Hectare)             float64
# Yield(Kg/Hectare)            float64
# dtype: object

# %% [markdown]
# ## how many countries from each continent produce sugarcane

# %%
data_1.nunique()
# Out:
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_person(Kg)    101
# Acreage(Hectare)             101
# Yield(Kg/Hectare)            102
# dtype: int64

# %%
data_1['Continent'].nunique()
# Out:
# 6

# %%
data_1['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
data_1['Continent'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Continent'>

# %% [markdown]
# ## univariate analysis

# %%
data_1.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %% [markdown]
# ## analysed the numerical column

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot(data_1["Production(Tons)"])
plt.subplot(2,2,2)
sns.distplot(data_1["Production_per_person(Kg)"])
plt.subplot(2,2,3)
sns.distplot(data_1["Acreage(Hectare)"])
plt.subplot(2,2,4)
sns.distplot(data_1["Yield(Kg/Hectare)"])
# Out:
# C:\Users\kakab\AppData\Local\Temp\ipykernel_3132\666976035.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_1["Production(Tons)"])
# C:\Users\kakab\AppData\Local\Temp\ipykernel_3132\666976035.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ## checking the ouliers

# %%
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.boxplot(data_1["Production(Tons)"])
plt.subplot(2,2,2)
sns.boxplot(data_1["Production_per_person(Kg)"])
plt.subplot(2,2,3)
sns.boxplot(data_1["Acreage(Hectare)"])
plt.subplot(2,2,4)
sns.boxplot(data_1["Yield(Kg/Hectare)"])
# Out:
# <Axes: ylabel='Yield(Kg/Hectare)'>

# %%
data_1.describe()
# Out:
#        Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# count      1.020000e+02                 102.000000      1.020000e+02
# mean       1.850372e+07              112952.435755      2.498981e+05
# std        8.419149e+07              176651.341929      1.137003e+06
# min        1.000000e+00                   0.000000      0.000000e+00
# 25%        6.251875e+04                3671.910000      1.104000e+03
# 50%        1.440044e+06               25572.500000      1.655800e+04
# 75%        6.426824e+06              146384.750000      8.047400e+04
# max        7.686784e+08              951087.000000      1.022620e+07
#
#        Yield(Kg/Hectare)
# count         102.000000
# mean        52628.078431
# std         30504.676683
# min            10.000000
# 25%         29072.025000
# 50%         54108.950000
# 75%         73282.700000
# max        129049.300000

# %% [markdown]
# ## bivariate analysis

# %%
data_1.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %%
data_new=data_1[["Country","Production(Tons)"]].set_index("Country")
data_new
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %%
data_new["Production_perct"]=data_new["Production(Tons)"]*100/data_new["Production(Tons)"].sum()

# %%
data_new
# Out:
#            Production(Tons)  Production_perct
# Country
# Brazil          768678382.0      4.072729e+01
# India           348448000.0      1.846200e+01
# China           123059739.0      6.520138e+00
# Thailand         87468496.0      4.634389e+00
# Pakistan         65450704.0      3.467809e+00
# ...                     ...               ...
# Spain                 394.0      2.087551e-05
# Lebanon                97.0      5.139401e-06
# Singapore              50.0      2.649176e-06
# Samoa                  12.0      6.358022e-07
# Syria                   1.0      5.298352e-08
#
# [102 rows x 2 columns]

# %%
data_new["Production_perct"].plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='Production_perct'>

# %%
data_new["Production_perct"].head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
data_new["Production_perct"].tail(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
ax = sns.barplot(data = data_new.head(10),  x= "Country", y = "Production(Tons)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\kakab\AppData\Local\Temp\ipykernel_3132\1673698944.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %% [markdown]
# ## which country has highest land?

# %%
data_new1=data_1[["Country","Acreage(Hectare)"]].set_index("Country")
data_new1
# Out:
#            Acreage(Hectare)
# Country
# Brazil           10226205.0
# India             4950000.0
# China             1675215.0
# Thailand          1336575.0
# Pakistan          1130820.0
# ...                     ...
# Spain                   9.0
# Lebanon                 3.0
# Singapore               2.0
# Samoa                   1.0
# Syria                   0.0
#
# [102 rows x 1 columns]

# %%
data_new1=data_new1.sort_values(by="Acreage(Hectare)",ascending=False)

# %%
data_new1
# Out:
#            Acreage(Hectare)
# Country
# Brazil           10226205.0
# India             4950000.0
# China             1675215.0
# Thailand          1336575.0
# Pakistan          1130820.0
# ...                     ...
# Spain                   9.0
# Lebanon                 3.0
# Singapore               2.0
# Samoa                   1.0
# Syria                   0.0
#
# [102 rows x 1 columns]

# %%
ax=sns.barplot(data=data_new1.head(10),x="Country",y="Acreage(Hectare)",color="red")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\kakab\AppData\Local\Temp\ipykernel_3132\3709860993.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %% [markdown]
# ## which country has highest yield per hectare ?

# %%
data_1.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %%
data_new2=data_1.sort_values("Yield(Kg/Hectare)",ascending=False)
ax=sns.barplot(data=data_new2.head(10),x="Country",y="Yield(Kg/Hectare)",color="red")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\kakab\AppData\Local\Temp\ipykernel_3132\2955983109.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %%
data_new2=data_1.sort_values("Production_per_person(Kg)",ascending=False)
ax=sns.barplot(data=data_new2.head(10),x="Country",y="Production_per_person(Kg)",color="red")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\kakab\AppData\Local\Temp\ipykernel_3132\4294749052.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %%
data_1.corr(numeric_only=True)
# Out:
#                            Production(Tons)  Production_per_person(Kg)  \
# Production(Tons)                   1.000000                   0.015000
# Production_per_person(Kg)          0.015000                   1.000000
# Acreage(Hectare)                   0.997550                   0.012557
# Yield(Kg/Hectare)                  0.132812                   0.017999
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)
# Production(Tons)                   0.997550           0.132812
# Production_per_person(Kg)          0.012557           0.017999
# Acreage(Hectare)                   1.000000           0.113433
# Yield(Kg/Hectare)                  0.113433           1.000000

# %%
data_new2=data_1.sort_values("Yield(Kg/Hectare)",ascending=False)
ax=sns.barplot(data=data_new2.head(10),x="Country",y="Yield(Kg/Hectare)",hue="Production(Tons)",color="red")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\kakab\AppData\Local\Temp\ipykernel_3132\3822747064.py:2: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   ax=sns.barplot(data=data_new2.head(10),x="Country",y="Yield(Kg/Hectare)",hue="Production(Tons)",color="red")
# C:\Users\kakab\AppData\Local\Temp\ipykernel_3132\3822747064.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %%
sns.heatmap(data_1.corr(numeric_only=True), annot = True, cmap="Greens")
# Out:
# <Axes: >

# %% [markdown]
# ## Do countries which yield more sugarcane per hectare produces more sugarcane in total?

# %%
sns.scatterplot(data = data_1, x = "Acreage(Hectare)", y = "Production(Tons)", hue = "Continent" )
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# ## Do countries which yield more sugarcane per hectare produces more sugarcane in total?

# %%
sns.scatterplot(data = data_1, x = "Yield(Kg/Hectare)" , y = "Production(Tons)", hue = "Continent")
# Out:
# <Axes: xlabel='Yield(Kg/Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# ## continent analysis

# %%
data_1.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_person(Kg)  \
# 0    Brazil  South America       768678382.0                   3668.531
# 1     India           Asia       348448000.0                 260721.000
# 2     China           Asia       123059739.0                  88287.000
# 3  Thailand           Asia        87468496.0                   1264.303
# 4  Pakistan           Asia        65450704.0                 324219.000
#
#    Acreage(Hectare)  Yield(Kg/Hectare)
# 0        10226205.0            75167.5
# 1         4950000.0            70393.5
# 2         1675215.0            73459.1
# 3         1336575.0            65442.2
# 4         1130820.0            57879.0

# %%
df_continent = data_1.groupby("Continent").sum()

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# ...

# %%
df_continent["number_of_countries"] = data_1.groupby("Continent").count()["Country"]

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# ...

# %% [markdown]
# ## Which continent produces maximum sugarcane?

# %%
ax=df_continent.sort_values(by="Production(Tons)",ascending=False)
sns.barplot(data=ax,x="Continent",y="Production(Tons)")
# Out:
# <Axes: xlabel='Continent', ylabel='Production(Tons)'>

# %% [markdown]
# ## Do number of countries in a Continent effects production of sugarcane?

# %%
continent_names = df_continent.index.to_list()
sns.lineplot(data = df_continent,x = "number_of_countries", y= "Production(Tons)" )
plt.xticks(df_continent["number_of_countries"], continent_names, rotation =90)
plt.show()

# %% [markdown]
# ## Do continent with highest land produces more sugarcane?

# %%
sns.lineplot(data = df_continent,x = "Acreage(Hectare)", y= "Production(Tons)" )
# Out:
# <Axes: xlabel='Acreage(Hectare)', ylabel='Production(Tons)'>

# %% [markdown]
# ## Production distribution by continent

# %%
df_continent
# Out:
#                                                          Country  \
# Continent
# Africa         EgyptSouth AfricaKenyaSwazilandSudanZambiaMaur...
# Asia           IndiaChinaThailandPakistanIndonesiaPhilippines...
# Europe                                             PortugalSpain
# North America  MexicoGuatemalaUnited States of AmericaCubaEl ...
# Oceania                       AustraliaFijiPapua New GuineaSamoa
# South America  BrazilColombiaArgentinaPeruEcuadorBoliviaParag...
#
#                Production(Tons)  Production_per_person(Kg)  Acreage(Hectare)  \
# Continent
# Africa               89681472.0                2332636.293         1439089.0
# Asia                721930425.0                1857769.303        10608319.0
# Europe                   5823.0                    536.000              71.0
# North America       173995947.0                3796081.508         1581983.0
# Oceania              36177574.0                  28593.605          490909.0
# ...

# %%
df_continent["Production(Tons)"].plot(kind = "pie", autopct = "%.2f%%")
plt.title('Production Distribution by Continent')
plt.show()

# %%
df_continent.corr(numeric_only=True)
# Out:
#                            Production(Tons)  Production_per_person(Kg)  \
# Production(Tons)                   1.000000                   0.522211
# Production_per_person(Kg)          0.522211                   1.000000
# Acreage(Hectare)                   0.994897                   0.463215
# Yield(Kg/Hectare)                  0.091201                   0.542961
# number_of_countries                0.109244                   0.540086
#
#                            Acreage(Hectare)  Yield(Kg/Hectare)  \
# Production(Tons)                   0.994897           0.091201
# Production_per_person(Kg)          0.463215           0.542961
# Acreage(Hectare)                   1.000000           0.111166
# Yield(Kg/Hectare)                  0.111166           1.000000
# number_of_countries                0.132817           0.989712
#
#                            number_of_countries
# Production(Tons)                      0.109244
# Production_per_person(Kg)             0.540086
# ...

# %%
#df_continent.corr(df_continent.corr(numeric_only=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_continent.corr(df_continent.corr(numeric_only=True))
#
# NameError: name 'df_continent' is not defined
